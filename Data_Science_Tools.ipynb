# %% [markdown]
# <a href="https://colab.research.google.com/github/sreelekaa/Data-Science-Tools/blob/main/Data_Science_Tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Science Tools and Ecosystem**

# %% [markdown]
# ## **Introduction**
# In this notebook, we summarize important tools and concepts used in the field of Data Science.

# %% [markdown]
# ### **Popular Languages Used in Data Science**
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ### **Commonly Used Libraries in Data Science**
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - ggplot2

# %% [markdown]
# ### Data Science Tools
# ---------------------------------------
# | Tool               |   Category         |
# |-------------------|------------------|
# | Jupyter Notebook  | IDE              |
# | RStudio           | IDE              |
# | Apache Spark      | Big Data Tool    |
# | TensorFlow        | Deep Learning    |
# | KNIME             | Data Mining Tool |

# %% [markdown]
# ### **Examples of Arithmetic Expressions**
# Below are examples of simple arithmetic expressions such as addition and multiplication.

# %%
# This code multiplies and adds numbers
(3 * 4) + 5
# Out:
# 17

# %%
# This code converts 200 minutes to hours
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ### **Objectives**
# - List popular languages for Data Science
# - Explore common libraries used by Data Scientists
# - Demonstrate arithmetic operations in Python
# - Convert time from minutes to hours
# - Create and format tables in markdown

# %% [markdown]
# ## **Author**
# Sreeleka Manickam
